# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_excel('/content/Nasabah BSI.xlsx')

# %%
data
# Out:
#           No Tanggal Buka Rekening Kode Cabang            Jenis Tabungan  \
# 0          1            2022-06-30   ID0018158  BSI TABUNGAN EASY WADIAH
# 1          2            2022-06-29   ID0018158  BSI TABUNGAN EASY WADIAH
# 2          3            2022-06-29   ID0018158  BSI TABUNGAN EASY WADIAH
# 3          4            2022-06-27   ID0018158  BSI TABUNGAN EASY WADIAH
# 4          5            2022-06-27   ID0018158  BSI TABUNGAN EASY WADIAH
# ...      ...                   ...         ...                       ...
# 11437  11438            2011-01-18   ID0018158  BSI TABUNGAN EASY WADIAH
# 11438  11439            2011-01-18   ID0018158  BSI TABUNGAN EASY WADIAH
# 11439  11440            2011-01-17   ID0018158  BSI TABUNGAN EASY WADIAH
# 11440  11441            2011-01-17   ID0018158  BSI TABUNGAN EASY WADIAH
# 11441  11442            2011-01-17   ID0018158  BSI TABUNGAN EASY WADIAH
#
#        No. Rekening No. Rekening Lama Mt. Uang                          Nama  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11442 entries, 0 to 11441
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   No                       11442 non-null  int64
#  1   Tanggal Buka Rekening    11442 non-null  datetime64[ns]
#  2   Kode Cabang              11442 non-null  object
#  3   Jenis Tabungan           11442 non-null  object
#  4   No. Rekening             11442 non-null  int64
#  5   No. Rekening Lama        3397 non-null   object
#  6   Mt. Uang                 11442 non-null  object
#  7   Nama                     11442 non-null  object
#  8   Gender                   11442 non-null  object
#  9   Alamat                   11442 non-null  object
#  10  Saldo Awal               11442 non-null  object
#  11  Mutasi Debit             11442 non-null  int64
#  12  Mutasi Kredit            11442 non-null  int64
#  13  Saldo Akhir              11442 non-null  int64
# ...

# %%
data.columns
# Out:
# Index(['No', 'Tanggal Buka Rekening', 'Kode Cabang', 'Jenis Tabungan',
#        'No. Rekening', 'No. Rekening Lama', 'Mt. Uang', 'Nama', 'Gender',
#        'Alamat', 'Saldo Awal', 'Mutasi Debit', 'Mutasi Kredit', 'Saldo Akhir',
#        'Kategori Saldo', 'Pekerjaan', 'Rekomendasi Program BSI'],
#       dtype='object')

# %%
data.isnull()
# Out:
#           No  Tanggal Buka Rekening  Kode Cabang  Jenis Tabungan  \
# 0      False                  False        False           False
# 1      False                  False        False           False
# 2      False                  False        False           False
# 3      False                  False        False           False
# 4      False                  False        False           False
# ...      ...                    ...          ...             ...
# 11437  False                  False        False           False
# 11438  False                  False        False           False
# 11439  False                  False        False           False
# 11440  False                  False        False           False
# 11441  False                  False        False           False
#
#        No. Rekening  No. Rekening Lama  Mt. Uang   Nama  Gender  Alamat  \
# 0             False              False     False  False   False   False
# ...

# %%
data.isnull().sum()
# Out:
# No                            0
# Tanggal Buka Rekening         0
# Kode Cabang                   0
# Jenis Tabungan                0
# No. Rekening                  0
# No. Rekening Lama          8045
# Mt. Uang                      0
# Nama                          0
# Gender                        0
# Alamat                        0
# Saldo Awal                    0
# Mutasi Debit                  0
# Mutasi Kredit                 0
# Saldo Akhir                   0
# Kategori Saldo                0
# Pekerjaan                     0
# Rekomendasi Program BSI       0
# dtype: int64

# %%
remove=['No','Tanggal Buka Rekening','Kode Cabang','Jenis Tabungan','Nama','No. Rekening','No. Rekening Lama','Alamat','Saldo Awal','Mutasi Debit','Mutasi Kredit','Saldo Akhir']

# %%
data.drop(remove,axis=1, inplace=True)

# %%
data
# Out:
#       Mt. Uang Gender Kategori Saldo            Pekerjaan  \
# 0          IDR      L        <5 Juta      Karyawan Swasta
# 1          IDR      L        <5 Juta  Mahasiswa / Pelajar
# 2          IDR      L        <5 Juta  Mahasiswa / Pelajar
# 3          IDR      L        <5 Juta  Mahasiswa / Pelajar
# 4          IDR      L        <5 Juta           Wiraswasta
# ...        ...    ...            ...                  ...
# 11437      IDR      P        <5 Juta           Wiraswasta
# 11438      IDR      P        <5 Juta           Wiraswasta
# 11439      IDR      P        <5 Juta      Karyawan Swasta
# 11440      IDR      P        <5 Juta      Karyawan Swasta
# 11441      IDR      P        <5 Juta     Ibu Rumah Tangga
#
#       Rekomendasi Program BSI
# 0      Tidak Direkomendasikan
# 1      Tidak Direkomendasikan
# 2      Tidak Direkomendasikan
# 3      Tidak Direkomendasikan
# 4      Tidak Direkomendasikan
# ...                       ...
# 11437  Tidak Direkomendasikan
# ...

# %%
data.to_excel('BSI.xlsx')
